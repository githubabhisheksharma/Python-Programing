# %%
import pandas as pd
import numpy as np

# %%
url ="https://www.basketball-reference.com/draft/NBA_2023.html"
BB_data = pd.read_html(url)
df = BB_data[0].head()
df
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0            Round 1  \
#                   Rk                 Pk                 Tm             Player
# 0                  1                  1                SAS  Victor Wembanyama
# 1                  2                  2                CHO     Brandon Miller
# 2                  3                  3                POR    Scoot Henderson
# 3                  4                  4                HOU      Amen Thompson
# 4                  5                  5                DET     Ausar Thompson
#
#            Unnamed: 5_level_0 Totals                   ... Shooting        \
#    College                Yrs      G    MP   PTS  TRB  ...      3P%   FT%
# 0      NaN                  1     71  2106  1522  755  ...     .325  .796
# 1  Alabama                  1     74  2383  1279  315  ...     .373  .827
# 2      NaN                  1     62  1765   868  194  ...     .325  .819
# ...

# %%
df[['Round 1','Per Game','Shooting']]
# Out:
#              Round 1          Per Game                  Shooting
#               Player  College       MP   PTS   TRB  AST      FG%   3P%   FT%
# 0  Victor Wembanyama      NaN     29.7  21.4  10.6  3.9     .465  .325  .796
# 1     Brandon Miller  Alabama     32.2  17.3   4.3  2.4     .440  .373  .827
# 2    Scoot Henderson      NaN     28.5  14.0   3.1  5.4     .385  .325  .819
# 3      Amen Thompson      NaN     22.4   9.5   6.6  2.6     .536  .138  .684
# 4     Ausar Thompson      NaN     25.1   8.8   6.4  1.9     .483  .186  .597

# %%
import pandas as pd
import numpy as pn
df = pd.read_csv(r'https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv',sep=';')
df.tail(2)
# Out:
#        age         job  marital            education default housing loan  \
# 41186   44  technician  married  professional.course      no      no   no
# 41187   74     retired  married  professional.course      no     yes   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 41186  cellular   nov         fri  ...         1    999         0
# 41187  cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 41186  nonexistent         -1.1          94.767          -50.8      1.028
# 41187      failure         -1.1          94.767          -50.8      1.028
#
#        nr.employed    y
# 41186       4963.6  yes
# 41187       4963.6   no
#
# [2 rows x 21 columns]

# %%
df.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
df.isnull()
# Out:
#          age    job  marital  education  default  housing   loan  contact  \
# 0      False  False    False      False    False    False  False    False
# 1      False  False    False      False    False    False  False    False
# 2      False  False    False      False    False    False  False    False
# 3      False  False    False      False    False    False  False    False
# 4      False  False    False      False    False    False  False    False
# ...      ...    ...      ...        ...      ...      ...    ...      ...
# 41183  False  False    False      False    False    False  False    False
# 41184  False  False    False      False    False    False  False    False
# 41185  False  False    False      False    False    False  False    False
# 41186  False  False    False      False    False    False  False    False
# 41187  False  False    False      False    False    False  False    False
#
#        month  day_of_week  ...  campaign  pdays  previous  poutcome  \
# ...

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df['age'].dtype
# Out:
# dtype('int64')

# %%
df.rename(columns={'age':'AGE'})
# Out:
#        AGE          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
import pandas as pd
import numpy as pn
df = pd.read_csv(r'https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv',sep=';')
df.to_csv('xyz.csv',index =False,header=False)

# %%
import pandas as pd
import numpy as pn
df = pd.read_csv(r'https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv',sep=';')
df = pd.date_range('1/1/2000',periods =7)
df
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
a = [1,2,3,4,5,6]
b = [98,7,6,5,4,3]
list(zip(a,b))
# Out:
# [(1, 98), (2, 7), (3, 6), (4, 5), (5, 4), (6, 3)]

# %%
obj = """ {
  "squadName": "Super hero squad",
  "homeTown": "Metro City",
  "formed": 2016,
  "secretBase": "Super tower",
  "active": true,
  "members": [
    {
      "name": "Molecule Man",
      "age": 29,
      "secretIdentity": "Dan Jukes",
      "powers": ["Radiation resistance", "Turning tiny", "Radiation blast"]
    },
    {
      "name": "Madame Uppercut",
      "age": 39,
      "secretIdentity": "Jane Wilson",
      "powers": [
        "Million tonne punch",
        "Damage resistance",
        "Superhuman reflexes"
      ]
    },
    {
      "name": "Eternal Flame",
      "age": 1000000,
      "secretIdentity": "Unknown",
      "powers": [
        "Immortality",
        "Heat Immunity",
        "Inferno",
        "Teleportation",
        "Interdimensional travel"
      ]
    }
  ]
}
"""
type(obj)
# Out:
# str

# %%
import json
result = json.loads(obj)
type(result)
# Out:
# dict

# %%
result['members']
# Out:
# [{'name': 'Molecule Man',
#   'age': 29,
#   'secretIdentity': 'Dan Jukes',
#   'powers': ['Radiation resistance', 'Turning tiny', 'Radiation blast']},
#  {'name': 'Madame Uppercut',
#   'age': 39,
#   'secretIdentity': 'Jane Wilson',
#   'powers': ['Million tonne punch',
#    'Damage resistance',
#    'Superhuman reflexes']},
#  {'name': 'Eternal Flame',
#   'age': 1000000,
#   'secretIdentity': 'Unknown',
#   'powers': ['Immortality',
#    'Heat Immunity',
#    'Inferno',
#    'Teleportation',
#    'Interdimensional travel']}]

# %%
import pandas as pd
m= pd.DataFrame(result['members'])
m
# Out:
#               name      age secretIdentity  \
# 0     Molecule Man       29      Dan Jukes
# 1  Madame Uppercut       39    Jane Wilson
# 2    Eternal Flame  1000000        Unknown
#
#                                               powers
# 0  [Radiation resistance, Turning tiny, Radiation...
# 1  [Million tonne punch, Damage resistance, Super...
# 2  [Immortality, Heat Immunity, Inferno, Teleport...

# %%
data = pd.read_json('E:\\exmp.json')
data
# Out:
#           squadName    homeTown  formed   secretBase  active  \
# 0  Super hero squad  Metro City    2016  Super tower    True
# 1  Super hero squad  Metro City    2016  Super tower    True
# 2  Super hero squad  Metro City    2016  Super tower    True
#
#                                              members
# 0  {'name': 'Molecule Man', 'age': 29, 'secretIde...
# 1  {'name': 'Madame Uppercut', 'age': 39, 'secret...
# 2  {'name': 'Eternal Flame', 'age': 1000000, 'sec...
